# %% [markdown]
# # mens-t20 worldcup 2024

# %%
# Python Libraries install

# !pip install numpy 
# !pip install pandas
# !pip install matplotlib
# !pip install seaborn

# %%
# importing python libraries

import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv(r"C:\Users\raghu\OneDrive\Desktop\sudeshna's folder\Data Analyst project\Data sets\mens_t20_world_cup_2024.csv")
data
# Out:
#               Player                      Team  Mat  Inns  NO  Runs   HS  \
# 0         NP Kenjige  United States of America    4     2   0     1    1
# 1        Aaron Jones  United States of America    6     6   2   162  94*
# 2       Aasif Sheikh                     Nepal    3     3   0    63   42
# 3       Abbas Afridi                  Pakistan    1     1   0    17   17
# 4          F Achelam                    Uganda    1     1   0     9    9
# ..               ...                       ...  ...   ...  ..   ...  ...
# 242          D Wiese                   Namibia    4     4   1    51   27
# 243    KS Williamson               New Zealand    4     3   1    28  18*
# 244         SA Yadav                     India    8     8   1   199   53
# 245          A Zampa                 Australia    7     1   0     9    9
# 246  Zeeshan Maqsood                      Oman    4     4   0    27   22
#
#        Ave      SR  100  50  0
# 0     0.50   25.00    0   0  1
# ...

# %%
data.head()
# Out:
#          Player                      Team  Mat  Inns  NO  Runs   HS   Ave  \
# 0    NP Kenjige  United States of America    4     2   0     1    1   0.5
# 1   Aaron Jones  United States of America    6     6   2   162  94*  40.5
# 2  Aasif Sheikh                     Nepal    3     3   0    63   42  21.0
# 3  Abbas Afridi                  Pakistan    1     1   0    17   17  17.0
# 4     F Achelam                    Uganda    1     1   0     9    9   9.0
#
#        SR  100  50  0
# 0   25.00    0   0  1
# 1  135.00    0   1  1
# 2   88.73    0   0  0
# 3   80.95    0   0  0
# 4   69.23    0   0  0

# %%
data.tail()
# Out:
#               Player         Team  Mat  Inns  NO  Runs   HS    Ave      SR  \
# 242          D Wiese      Namibia    4     4   1    51   27  17.00  127.50
# 243    KS Williamson  New Zealand    4     3   1    28  18*  14.00   87.50
# 244         SA Yadav        India    8     8   1   199   53  28.42  135.37
# 245          A Zampa    Australia    7     1   0     9    9   9.00  128.57
# 246  Zeeshan Maqsood         Oman    4     4   0    27   22   6.75   75.00
#
#      100  50  0
# 242    0   0  0
# 243    0   0  0
# 244    0   2  0
# 245    0   0  0
# 246    0   0  0

# %%
data.shape
# Out:
# (247, 12)

# %%
data.columns
# Out:
# Index(['Player', 'Team', 'Mat', 'Inns', 'NO', 'Runs', 'HS', 'Ave', 'SR', '100',
#        '50', '0'],
#       dtype='object')

# %%
print(len(data.columns))
# Out:
# 12

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 247 entries, 0 to 246
# Data columns (total 12 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Player  247 non-null    object
#  1   Team    247 non-null    object
#  2   Mat     247 non-null    int64
#  3   Inns    247 non-null    int64
#  4   NO      247 non-null    int64
#  5   Runs    247 non-null    int64
#  6   HS      247 non-null    object
#  7   Ave     247 non-null    float64
#  8   SR      247 non-null    float64
#  9   100     247 non-null    int64
#  10  50      247 non-null    int64
#  11  0       247 non-null    int64
# dtypes: float64(2), int64(7), object(3)
# memory usage: 23.3+ KB

# %%
data.isna()
# Out:
#      Player   Team    Mat   Inns     NO   Runs     HS    Ave     SR    100  \
# 0     False  False  False  False  False  False  False  False  False  False
# 1     False  False  False  False  False  False  False  False  False  False
# 2     False  False  False  False  False  False  False  False  False  False
# 3     False  False  False  False  False  False  False  False  False  False
# 4     False  False  False  False  False  False  False  False  False  False
# ..      ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 242   False  False  False  False  False  False  False  False  False  False
# 243   False  False  False  False  False  False  False  False  False  False
# 244   False  False  False  False  False  False  False  False  False  False
# 245   False  False  False  False  False  False  False  False  False  False
# 246   False  False  False  False  False  False  False  False  False  False
#
#         50      0
# 0    False  False
# 1    False  False
# ...

# %%
data.isnull().any()
# Out:
# Player    False
# Team      False
# Mat       False
# Inns      False
# NO        False
# Runs      False
# HS        False
# Ave       False
# SR        False
# 100       False
# 50        False
# 0         False
# dtype: bool

# %%
data.isna().sum()
# Out:
# Player    0
# Team      0
# Mat       0
# Inns      0
# NO        0
# Runs      0
# HS        0
# Ave       0
# SR        0
# 100       0
# 50        0
# 0         0
# dtype: int64

# %%
data.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 242    False
# 243    False
# 244    False
# 245    False
# 246    False
# Length: 247, dtype: bool

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data['Inns']
# Out:
# 0      2
# 1      6
# 2      3
# 3      1
# 4      1
#       ..
# 242    4
# 243    3
# 244    8
# 245    1
# 246    4
# Name: Inns, Length: 247, dtype: int64

# %%
data['Team'].head(20)
# Out:
# 0     United States of America
# 1     United States of America
# 2                        Nepal
# 3                     Pakistan
# 4                       Uganda
# 5                      Ireland
# 6                    Australia
# 7                        Nepal
# 8                      England
# 9     United States of America
# 10                 New Zealand
# 11            Papua New Guinea
# 12    United States of America
# 13                        Oman
# 14                     England
# 15                       India
# 16                   Sri Lanka
# 17                        Oman
# 18                        Oman
# 19                    Pakistan
# Name: Team, dtype: object

# %%
data['Team']== 'India'
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 242    False
# 243    False
# 244     True
# 245    False
# 246    False
# Name: Team, Length: 247, dtype: bool

# %%
(data['Team']=='India').sum()       #Method-->1
# Out:
# 11

# %%
team = data['Team']
count =0
for i in team:                               # Method-->2
    if i=='India':
        print(i)
        count+=1
print(count)
# Out:
# India
# India
# India
# India
# India
# India
# India
# India
# India
# India
# India
# 11

# %%
data.describe()
# Out:
#               Mat        Inns          NO        Runs         Ave          SR  \
# count  247.000000  247.000000  247.000000  247.000000  247.000000  247.000000
# mean     4.408907    3.449393    0.700405   49.149798   14.176275   88.911781
# std      2.235796    2.009244    0.835761   58.137259   14.191932   46.135606
# min      1.000000    1.000000    0.000000    0.000000    0.000000    0.000000
# 25%      3.000000    2.000000    0.000000    8.000000    4.000000   59.165000
# 50%      4.000000    3.000000    1.000000   25.000000   11.000000   92.850000
# 75%      6.500000    4.000000    1.000000   71.000000   21.250000  120.955000
# max      9.000000    9.000000    4.000000  281.000000  102.000000  250.000000
#
#          100          50           0
# count  247.0  247.000000  247.000000
# mean     0.0    0.186235    0.453441
# std      0.0    0.515741    0.635068
# min      0.0    0.000000    0.000000
# 25%      0.0    0.000000    0.000000
# 50%      0.0    0.000000    0.000000
# ...

# %%
data["NO"].value_counts()
# Out:
# NO
# 0    121
# 1     91
# 2     24
# 3     10
# 4      1
# Name: count, dtype: int64

# %%
data['Mat'].unique()
# Out:
# array([4, 6, 3, 1, 2, 8, 5, 7, 9], dtype=int64)

# %%
(data['Mat'].unique()).sum()
# Out:
# 45

# %%
print(len(data['Mat'].unique()))
# Out:
# 9

# %%
data[['Player', 'Team', 'Runs']].head(15)
# Out:
#           Player                      Team  Runs
# 0     NP Kenjige  United States of America     1
# 1    Aaron Jones  United States of America   162
# 2   Aasif Sheikh                     Nepal    63
# 3   Abbas Afridi                  Pakistan    17
# 4      F Achelam                    Uganda     9
# 5       MR Adair                   Ireland    52
# 6        AC Agar                 Australia     2
# 7       DS Airee                     Nepal    32
# 8         MM Ali                   England    71
# 9       Ali Khan  United States of America    14
# 10      FH Allen               New Zealand    35
# 11     CJA Amini          Papua New Guinea    34
# 12   CJ Anderson  United States of America    66
# 13    Aqib Ilyas                      Oman    42
# 14     JC Archer                   England    22

# %%
data[data.index==200]
# Out:
#          Player       Team  Mat  Inns  NO  Runs HS  Ave     SR  100  50  0
# 200  MD Shanaka  Sri Lanka    3     3   0    12  9  4.0  66.66    0   0  1

# %%
data[data.index.isin(range(1, 15))]
# Out:
#           Player                      Team  Mat  Inns  NO  Runs   HS    Ave  \
# 1    Aaron Jones  United States of America    6     6   2   162  94*  40.50
# 2   Aasif Sheikh                     Nepal    3     3   0    63   42  21.00
# 3   Abbas Afridi                  Pakistan    1     1   0    17   17  17.00
# 4      F Achelam                    Uganda    1     1   0     9    9   9.00
# 5       MR Adair                   Ireland    3     3   0    52   34  17.33
# 6        AC Agar                 Australia    2     1   0     2    2   2.00
# 7       DS Airee                     Nepal    3     3   0    32   25  10.66
# 8         MM Ali                   England    8     5   0    71   25  14.20
# 9       Ali Khan  United States of America    6     2   1    14  14*  14.00
# 10      FH Allen               New Zealand    4     4   0    35   26   8.75
# 11     CJA Amini          Papua New Guinea    3     3   0    34   17  11.33
# ...

# %%
sort = data.sort_values(by='Runs', ascending=False)    # Method--->1
sort.head(10)
# Out:
#                  Player                      Team  Mat  Inns  NO  Runs   HS  \
# 179  Rahmanullah Gurbaz               Afghanistan    8     8   0   281   80
# 202           RG Sharma                     India    8     8   1   257   92
# 75              TM Head                 Australia    7     7   1   255   76
# 47            Q de Kock              South Africa    9     9   0   243   74
# 82       Ibrahim Zadran               Afghanistan    8     8   0   231   70
# 173            N Pooran               West Indies    7     7   1   228   98
# 65             AGS Gous  United States of America    6     6   1   219  80*
# 36           JC Buttler                   England    8     7   2   214  83*
# 244            SA Yadav                     India    8     8   1   199   53
# 105           H Klaasen              South Africa    9     8   2   190   52
#
#        Ave      SR  100  50  0
# 179  35.12  124.33    0   3  2
# 202  36.71  156.70    0   3  0
# 75   42.50  158.38    0   2  1
# ...

# %%
data['Runs'].nlargest(n=10)     # Method--->2
# Out:
# 179    281
# 202    257
# 75     255
# 47     243
# 82     231
# 173    228
# 65     219
# 36     214
# 244    199
# 105    190
# Name: Runs, dtype: int64

# %%
sort = data.sort_values(by='Runs', ascending=False)          # bar graph using sorting and top 10 highest runs
top_10 = sort.head(10)

sns.barplot(x=top_10.index, y='Runs', data=top_10)
plt.xlabel('Index')
plt.ylabel('Runs')
plt.title('Top 10 Runs')
plt.show()

# %%
'''sort = data.sort_values(by='Runs', ascending=False)
top_10 = sort.head(10)
bar_labels = ['red', 'blue', 'green', 'orange', 'pink', 'brown', 'skyblue', 'yellow', 'violet', 'grey']
bar_colors = ['tab:red', 'tab:blue', 'tab:red', 'tab:orange', 'tab:pink', 'tab:brown', 'tab:skyblue', 'tab:yellow', 'tab:violet', 'tab:grey']
sns.barplot(x=top_10.index, y='Runs', data=top_10, label = bar_labels, color = bar_colors)
plt.xlabel('Index')
plt.ylabel('Runs')
plt.title('Top 10 Runs')
plt.show()'''
# Out:
# "sort = data.sort_values(by='Runs', ascending=False)\ntop_10 = sort.head(10)\nbar_labels = ['red', 'blue', 'green', 'orange', 'pink', 'brown', 'skyblue', 'yellow', 'violet', 'grey']\nbar_colors = ['tab:red', 'tab:blue', 'tab:red', 'tab:orange', 'tab:pink', 'tab:brown', 'tab:skyblue', 'tab:yellow', 'tab:violet', 'tab:grey']\nsns.barplot(x=top_10.index, y='Runs', data=top_10, label = bar_labels, color = bar_colors)\nplt.xlabel('Index')\nplt.ylabel('Runs')\nplt.title('Top 10 Runs')\nplt.show()"

# %%
data1 = data[['Team', 'Runs']].head(30)
sns.barplot(data = data1, y='Team', x='Runs')
# Out:
# <Axes: xlabel='Runs', ylabel='Team'>

# %%
sns.barplot(data = data, x='Team', y='NO')
# Out:
# <Axes: xlabel='Team', ylabel='NO'>

# %%
data = (data[data['Mat']>3]).head(10)
sns.lineplot(data=data, x= 'Team', y='Mat')
# Out:
# <Axes: xlabel='Team', ylabel='Mat'>

# %%
data1=data[data.index.isin(range(2,100))]
df=data1.loc[data1['Inns']<8]
sns.lineplot(data=df ,x='Team',y='Inns')
# Out:
# C:\Users\raghu\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\raghu\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='Team', ylabel='Inns'>

# %%
sns.countplot(x='Team', data=data)
# Out:
# <Axes: xlabel='Team', ylabel='count'>

# %%
data_range = data[data.index.isin(range(0, 247))]
sns.countplot(y='Inns', data=data_range)
# Out:
# <Axes: xlabel='count', ylabel='Inns'>

# %%
plt.figure(figsize=(10,20))
sns.scatterplot(data=data['Inns'],x=data['SR'],y=data['Player'],hue=data['Team'])
# Out:
# <Axes: xlabel='SR', ylabel='Player'>

# %%
sns.histplot(data = data, x=data['Runs'], y=data['Team'], color='Blue')
# Out:
# <Axes: xlabel='Runs', ylabel='Team'>

# %%
data.columns
# Out:
# Index(['Player', 'Team', 'Mat', 'Inns', 'NO', 'Runs', 'HS', 'Ave', 'SR', '100',
#        '50', '0'],
#       dtype='object')

# %%
data.head()
# Out:
#          Player                      Team  Mat  Inns  NO  Runs   HS   Ave  \
# 0    NP Kenjige  United States of America    4     2   0     1    1   0.5
# 1   Aaron Jones  United States of America    6     6   2   162  94*  40.5
# 2  Aasif Sheikh                     Nepal    3     3   0    63   42  21.0
# 3  Abbas Afridi                  Pakistan    1     1   0    17   17  17.0
# 4     F Achelam                    Uganda    1     1   0     9    9   9.0
#
#        SR  100  50  0
# 0   25.00    0   0  1
# 1  135.00    0   1  1
# 2   88.73    0   0  0
# 3   80.95    0   0  0
# 4   69.23    0   0  0

# %%
data=data.head(20)
sns.stripplot(x='Player', y='SR', data=data)
# Out:
# <Axes: xlabel='Player', ylabel='SR'>

# %%
sp=data['Mat'].head(15)
mp=data['Inns'].head(15)

plt.figure(figsize=(10, 5))
plt.subplot(141)
plt.plot(mp, sp)
plt.subplot(142)
plt.bar(mp, sp)
plt.subplot(143)
plt.scatter(mp, sp)
plt.title('Numeric Plotting btw DiscountsAvailed and ProductCategory')
plt.show()

# %%
data=data.head(200)
sns.pairplot(data[['Mat', 'Inns', 'NO', 'Runs', 'Ave', 'SR']])
# Out:
# C:\Users\raghu\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\raghu\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\raghu\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %%
data=data.head(10)
x=data['Player']
sizes=data['Inns']
plt.pie(sizes, labels=x, startangle=90, wedgeprops={"edgecolor":"black"}, autopct='%1.1f%%', explode =[0,0.1,0,0.2,0.3,0,0.5,0,0.1,0.4])
#plot=data.plot.pie(subplots=True, fig=(6,4))
plt.show()

# %%
data=data[['Team','Mat']].head()
plot=data.plot.pie(x='Team', y='Mat',  wedgeprops={"edgecolor":"black"}, figsize=(6,6))
plot=data.plot.pie(subplots=True, fig=(6,4))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[234], line 3
#       1 data=data[['Team','Mat']].head()
#       2 plot=data.plot.pie(x='Team', y='Mat',  wedgeprops={"edgecolor":"black"}, figsize=(6,6))
# ----> 3 plot=data.plot.pie(subplots=True, fig=(6,4))
#
# File ~\anaconda3\Lib\site-packages\pandas\plotting\_core.py:1661, in PlotAccessor.pie(self, **kwargs)
#    1655 if (
#    1656     isinstance(self._parent, ABCDataFrame)
#    1657     and kwargs.get("y", None) is None
#    1658     and not kwargs.get("subplots", False)
#    1659 ):
#    1660     raise ValueError("pie requires either y column or 'subplots=True'")
# -> 1661 return self(kind="pie", **kwargs)
#
# File ~\anaconda3\Lib\site-packages\pandas\plotting\_core.py:1031, in PlotAccessor.__call__(self, *args, **kwargs)
#    1028             label_name = label_kw or data.columns
# ...

# %%
data=data.drop(['Player', 'Team', 'HS'], axis=1)
correlation=data.corr()
correlation['Mat'].sort_values(ascending=True)
# Out:
# 0       0.126549
# Ave     0.309081
# 50      0.335578
# NO      0.433480
# SR      0.440176
# Runs    0.567612
# Inns    0.735331
# Mat     1.000000
# 100          NaN
# Name: Mat, dtype: float64

# %%
plt.figure(figsize=(9,9))
sns.heatmap(data=correlation, cmap="Paired", square=True, linewidth=1.6, annot=True)
plt.title('Correlation Matrix')
plt.show()
# Out:
# C:\Users\raghu\anaconda3\Lib\site-packages\seaborn\matrix.py:260: FutureWarning: Format strings passed to MaskedConstant are ignored, but in future may error or produce different behavior
#   annotation = ("{:" + self.fmt + "}").format(val)

# %%
data.head()
# Out:
#    Mat  Inns  NO  Runs   HS   Ave      SR  100  50  0
# 0    4     2   0     1    1   0.5   25.00    0   0  1
# 1    6     6   2   162  94*  40.5  135.00    0   1  1
# 2    3     3   0    63   42  21.0   88.73    0   0  0
# 3    1     1   0    17   17  17.0   80.95    0   0  0
# 4    1     1   0     9    9   9.0   69.23    0   0  0
