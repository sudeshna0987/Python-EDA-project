# %% [markdown]
# # Analyze and Predict Customer Satisfaction in Restaurants

# %%
# Python Libraries install

# !pip install numpy 
# !pip install pandas
# !pip install matplotlib
# !pip install seaborn

# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
dataset = pd.read_csv(r"C:\Users\raghu\OneDrive\Desktop\sudeshna's folder\Data Analyst project\Data sets\restaurant_customer_satisfaction.csv")

# %%
dataset
# Out:
#       CustomerID  Age  Gender  Income VisitFrequency  AverageSpend  \
# 0            654   35    Male   83380         Weekly     27.829142
# 1            655   19    Male   43623         Rarely    115.408622
# 2            656   41  Female   83737         Weekly    106.693771
# 3            657   43    Male   96768         Rarely     43.508508
# 4            658   55  Female   67937        Monthly    148.084627
# ...          ...  ...     ...     ...            ...           ...
# 1495        2149   39    Male  114857        Monthly    163.015254
# 1496        2150   37  Female  133506         Weekly    190.991911
# 1497        2151   46    Male  119159        Monthly    150.088604
# 1498        2152   24    Male   27970         Weekly    196.363626
# 1499        2153   51    Male  148333         Weekly    171.119498
#
#      PreferredCuisine TimeOfVisit  GroupSize DiningOccasion  MealType  \
# 0             Chinese   Breakfast          3       Business  Takeaway
# ...

# %%
dataset.head()
# Out:
#    CustomerID  Age  Gender  Income VisitFrequency  AverageSpend  \
# 0         654   35    Male   83380         Weekly     27.829142
# 1         655   19    Male   43623         Rarely    115.408622
# 2         656   41  Female   83737         Weekly    106.693771
# 3         657   43    Male   96768         Rarely     43.508508
# 4         658   55  Female   67937        Monthly    148.084627
#
#   PreferredCuisine TimeOfVisit  GroupSize DiningOccasion  MealType  \
# 0          Chinese   Breakfast          3       Business  Takeaway
# 1         American      Dinner          1         Casual   Dine-in
# 2         American      Dinner          6    Celebration   Dine-in
# 3           Indian       Lunch          1    Celebration   Dine-in
# 4          Chinese   Breakfast          1       Business  Takeaway
#
#    OnlineReservation  DeliveryOrder  LoyaltyProgramMember   WaitTime  \
# 0                  0              1                     1  43.523929
# ...

# %%
dataset.tail()
# Out:
#       CustomerID  Age  Gender  Income VisitFrequency  AverageSpend  \
# 1495        2149   39    Male  114857        Monthly    163.015254
# 1496        2150   37  Female  133506         Weekly    190.991911
# 1497        2151   46    Male  119159        Monthly    150.088604
# 1498        2152   24    Male   27970         Weekly    196.363626
# 1499        2153   51    Male  148333         Weekly    171.119498
#
#      PreferredCuisine TimeOfVisit  GroupSize DiningOccasion  MealType  \
# 1495         American       Lunch          2       Business   Dine-in
# 1496          Italian       Lunch          4         Casual  Takeaway
# 1497         American       Lunch          4         Casual   Dine-in
# 1498          Italian      Dinner          6         Casual   Dine-in
# 1499          Chinese   Breakfast          4         Casual   Dine-in
#
#       OnlineReservation  DeliveryOrder  LoyaltyProgramMember   WaitTime  \
# ...

# %%
dataset.columns
# Out:
# Index(['CustomerID', 'Age', 'Gender', 'Income', 'VisitFrequency',
#        'AverageSpend', 'PreferredCuisine', 'TimeOfVisit', 'GroupSize',
#        'DiningOccasion', 'MealType', 'OnlineReservation', 'DeliveryOrder',
#        'LoyaltyProgramMember', 'WaitTime', 'ServiceRating', 'FoodRating',
#        'AmbianceRating', 'HighSatisfaction'],
#       dtype='object')

# %%
print(len(dataset.columns))
# Out:
# 19

# %%
dataset.shape
# Out:
# (1500, 19)

# %%
dataset.isnull().sum()
# Out:
# CustomerID              0
# Age                     0
# Gender                  0
# Income                  0
# VisitFrequency          0
# AverageSpend            0
# PreferredCuisine        0
# TimeOfVisit             0
# GroupSize               0
# DiningOccasion          0
# MealType                0
# OnlineReservation       0
# DeliveryOrder           0
# LoyaltyProgramMember    0
# WaitTime                0
# ServiceRating           0
# FoodRating              0
# AmbianceRating          0
# HighSatisfaction        0
# dtype: int64

# %%
dataset.isna().any()
# Out:
# CustomerID              False
# Age                     False
# Gender                  False
# Income                  False
# VisitFrequency          False
# AverageSpend            False
# PreferredCuisine        False
# TimeOfVisit             False
# GroupSize               False
# DiningOccasion          False
# MealType                False
# OnlineReservation       False
# DeliveryOrder           False
# LoyaltyProgramMember    False
# WaitTime                False
# ServiceRating           False
# FoodRating              False
# AmbianceRating          False
# HighSatisfaction        False
# dtype: bool

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1500 entries, 0 to 1499
# Data columns (total 19 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   CustomerID            1500 non-null   int64
#  1   Age                   1500 non-null   int64
#  2   Gender                1500 non-null   object
#  3   Income                1500 non-null   int64
#  4   VisitFrequency        1500 non-null   object
#  5   AverageSpend          1500 non-null   float64
#  6   PreferredCuisine      1500 non-null   object
#  7   TimeOfVisit           1500 non-null   object
#  8   GroupSize             1500 non-null   int64
#  9   DiningOccasion        1500 non-null   object
#  10  MealType              1500 non-null   object
#  11  OnlineReservation     1500 non-null   int64
#  12  DeliveryOrder         1500 non-null   int64
#  13  LoyaltyProgramMember  1500 non-null   int64
#  14  WaitTime              1500 non-null   float64
# ...

# %%
dataset.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1495    False
# 1496    False
# 1497    False
# 1498    False
# 1499    False
# Length: 1500, dtype: bool

# %%
dataset.duplicated().sum()
# Out:
# 0

# %%
dataset['PreferredCuisine']
# Out:
# 0        Chinese
# 1       American
# 2       American
# 3         Indian
# 4        Chinese
#           ...
# 1495    American
# 1496     Italian
# 1497    American
# 1498     Italian
# 1499     Chinese
# Name: PreferredCuisine, Length: 1500, dtype: object

# %%
dataset['PreferredCuisine'].head(15)
# Out:
# 0      Chinese
# 1     American
# 2     American
# 3       Indian
# 4      Chinese
# 5      Chinese
# 6       Indian
# 7      Mexican
# 8       Indian
# 9      Italian
# 10    American
# 11     Italian
# 12    American
# 13     Italian
# 14    American
# Name: PreferredCuisine, dtype: object

# %%
dataset['TimeOfVisit'] == 'Breakfast'
# Out:
# 0        True
# 1       False
# 2       False
# 3       False
# 4        True
#         ...
# 1495    False
# 1496    False
# 1497    False
# 1498    False
# 1499     True
# Name: TimeOfVisit, Length: 1500, dtype: bool

# %%
(dataset['TimeOfVisit'] == 'Breakfast').sum()
# Out:
# 506

# %%
value = dataset['ServiceRating']
count = 0
for p in value:
    if p >= 4:
        print(p)
        count+=1
print("count values equal to: ", count)
# Out:
# 5
# 4
# 4
# 5
# 4
# 4
# 5
# 4
# 4
# 5
# 5
# 4
# 5
# 5
# 5
# 5
# 5
# 4
# 5
# 5
# 5
# 5
# 5
# 5
# 4
# 5
# 5
# 5
# 4
# 4
# 4
# 5
# 5
# 5
# 4
# 4
# 5
# 4
# 4
# 4
# 5
# 4
# 4
# 4
# 4
# 4
# 5
# 4
# 5
# 5
# 5
# 4
# 5
# 4
# 5
# 4
# 5
# 5
# 4
# 4
# 5
# 4
# 5
# 4
# 4
# 4
# 5
# 5
# 4
# 4
# 5
# 5
# 5
# 5
# 4
# 4
# 4
# 4
# 5
# 4
# 4
# 5
# 5
# 4
# 5
# 4
# 4
# 4
# 5
# 4
# 5
# 5
# 4
# 5
# 4
# 4
# 4
# 4
# 4
# 5
# 4
# 5
# 5
# 4
# 5
# 4
# 5
# 4
# 5
# 4
# 4
# 4
# 5
# 5
# 5
# 5
# 4
# 5
# 4
# 5
# 4
# 4
# 4
# 5
# 5
# 5
# 4
# 5
# 4
# 5
# 4
# 4
# 5
# 5
# 4
# 4
# 5
# 4
# 4
# 4
# 5
# 4
# 4
# 5
# 5
# 4
# 4
# 4
# 5
# 5
# 5
# 5
# 5
# 4
# 5
# 5
# 5
# 5
# 4
# 4
# 4
# 4
# 5
# 4
# 5
# 5
# 5
# 5
# 4
# 4
# 5
# 5
# 5
# 4
# 4
# 4
# 5
# 4
# 5
# 5
# 4
# 5
# 4
# 4
# 4
# 4
# 5
# 4
# 4
# 5
# 4
# 4
# 4
# 4
# 5
# 4
# 4
# 4
# 5
# 4
# 5
# 4
# 4
# 4
# 4
# 5
# 4
# 5
# 4
# 5
# 5
# 4
# 4
# 4
# 4
# 5
# 4
# 5
# 5
# 5
# 5
# 5
# 5
# 4
# 4
# 5
# 4
# 4
# 5
# 5
# 5
# 5
# 4
# 5
# 5
# 5
# 4
# 4
# 4
# 4
# 4
# 5
# 4
# 5
# 4
# 5
# 5
# 5
# 4
# 5
# ...

# %%
dataset.describe()
# Out:
#         CustomerID          Age         Income  AverageSpend    GroupSize  \
# count  1500.000000  1500.000000    1500.000000   1500.000000  1500.000000
# mean   1403.500000    43.832000   85921.890000    105.659004     5.035333
# std     433.157015    14.967157   38183.051749     52.381849     2.558864
# min     654.000000    18.000000   20012.000000     10.306127     1.000000
# 25%    1028.750000    31.750000   52444.000000     62.287907     3.000000
# 50%    1403.500000    44.000000   85811.000000    104.626408     5.000000
# 75%    1778.250000    57.000000  119159.250000    148.649330     7.000000
# max    2153.000000    69.000000  149875.000000    199.973527     9.000000
#
#        OnlineReservation  DeliveryOrder  LoyaltyProgramMember     WaitTime  \
# count        1500.000000    1500.000000           1500.000000  1500.000000
# mean            0.296667       0.405333              0.480000    30.163550
# std             0.456941       0.491120              0.499766    17.214184
# ...

# %%
dataset['TimeOfVisit'].value_counts()
# Out:
# TimeOfVisit
# Breakfast    506
# Lunch        502
# Dinner       492
# Name: count, dtype: int64

# %%
print(len(dataset['TimeOfVisit'].value_counts()))
# Out:
# 3

# %%
dataset['FoodRating'].unique()
# Out:
# array([5, 4, 3, 2, 1], dtype=int64)

# %%
dataset[['CustomerID','PreferredCuisine', 'WaitTime', 'TimeOfVisit']].head(10)
# Out:
#    CustomerID PreferredCuisine   WaitTime TimeOfVisit
# 0         654          Chinese  43.523929   Breakfast
# 1         655         American  57.524294      Dinner
# 2         656         American  48.682623      Dinner
# 3         657           Indian   7.552993       Lunch
# 4         658          Chinese  37.789041   Breakfast
# 5         659          Chinese  26.853298      Dinner
# 6         660           Indian   7.927917       Lunch
# 7         661          Mexican  56.447210      Dinner
# 8         662           Indian  39.568188   Breakfast
# 9         663          Italian  20.782469       Lunch

# %%
sorting= dataset.sort_values(by='Income', ascending=False)
sorting.head(10)
# Out:
#       CustomerID  Age  Gender  Income VisitFrequency  AverageSpend  \
# 861         1515   40    Male  149875         Weekly    116.279303
# 1122        1776   45  Female  149856         Rarely     44.519643
# 1272        1926   31  Female  149807         Rarely    167.184428
# 570         1224   32  Female  149728        Monthly    156.869604
# 884         1538   56    Male  149720         Weekly     51.888609
# 855         1509   26  Female  149692         Weekly    110.448589
# 238          892   37  Female  149658          Daily     24.919682
# 54           708   36  Female  149655        Monthly     64.443562
# 461         1115   37  Female  149652          Daily    178.992240
# 8            662   27    Male  149638         Weekly     56.558632
#
#      PreferredCuisine TimeOfVisit  GroupSize DiningOccasion  MealType  \
# 861            Indian       Lunch          8    Celebration   Dine-in
# 1122          Italian       Lunch          2         Casual   Dine-in
# ...

# %%
dataset[dataset.index.isin(range(0,20))]
# Out:
#     CustomerID  Age  Gender  Income VisitFrequency  AverageSpend  \
# 0          654   35    Male   83380         Weekly     27.829142
# 1          655   19    Male   43623         Rarely    115.408622
# 2          656   41  Female   83737         Weekly    106.693771
# 3          657   43    Male   96768         Rarely     43.508508
# 4          658   55  Female   67937        Monthly    148.084627
# 5          659   42  Female   28860        Monthly    111.064696
# 6          660   20  Female  131104         Weekly    120.236707
# 7          661   51  Female  137882         Weekly    160.979098
# 8          662   27    Male  149638         Weekly     56.558632
# 9          663   32  Female  136145         Weekly     65.753455
# 10         664   21    Male   79249        Monthly     39.235383
# 11         665   59    Male   94208         Weekly    132.994918
# 12         666   32  Female  143471        Monthly    156.130808
# ...

# %%
dataset[dataset.index == 1400]
# Out:
#       CustomerID  Age Gender  Income VisitFrequency  AverageSpend  \
# 1400        2054   26   Male   87899        Monthly    186.530784
#
#      PreferredCuisine TimeOfVisit  GroupSize DiningOccasion MealType  \
# 1400         American       Lunch          4         Casual  Dine-in
#
#       OnlineReservation  DeliveryOrder  LoyaltyProgramMember   WaitTime  \
# 1400                  0              1                     0  20.212652
#
#       ServiceRating  FoodRating  AmbianceRating  HighSatisfaction
# 1400              4           4               5                 0

# %%
dataset.plot()
# Out:
# <Axes: >

# %%
dataset['WaitTime'].head(10).plot()
# Out:
# <Axes: >

# %%
dataset['Age'].nlargest(n=10)
# Out:
# 13     69
# 182    69
# 185    69
# 257    69
# 266    69
# 307    69
# 380    69
# 382    69
# 449    69
# 452    69
# Name: Age, dtype: int64

# %%
sorting= dataset.sort_values(by='Income', ascending=False)
top_10=sorting.head(10)

sns.lineplot(x='AverageSpend', y=top_10.index, data=top_10)
plt.xlabel('AverageSpend')
plt.ylabel('Index')
plt.title('Barchart of top 10 values in AverageSpend')
plt.show()

# %%
data=dataset[['Gender', 'Income']].head(20)
sns.barplot(data=data, y='Income', x='Gender')
# Out:
# <Axes: xlabel='Gender', ylabel='Income'>

# %%
data=(dataset[dataset['CustomerID']&dataset['ServiceRating']>2]).head(10)
sns.lineplot(data=data, x='WaitTime', y='CustomerID')
# Out:
# <Axes: xlabel='WaitTime', ylabel='CustomerID'>

# %%
data=dataset[dataset.index.isin(range(2, 20))]
data1=data.loc[data['FoodRating']<5]
sns.lineplot(data=data, x='CustomerID', y='FoodRating')
# Out:
# <Axes: xlabel='CustomerID', ylabel='FoodRating'>

# %%
dataset=dataset.head(100)
sns.countplot(x='FoodRating', data=dataset, hue='Gender')
# Out:
# <Axes: xlabel='FoodRating', ylabel='count'>

# %%
dataset=dataset.head(100)
sns.countplot(y='ServiceRating', data=dataset)
#plt.figure(figsize=(1,1))
plt.show()

# %%
plt.figure(figsize=(8,8))
dataset=dataset.head(20)
sns.scatterplot(data=dataset['FoodRating'], x=dataset['PreferredCuisine'], y=dataset['ServiceRating'], hue=dataset['CustomerID'], palette='Paired')
# Out:
# <Axes: xlabel='PreferredCuisine', ylabel='ServiceRating'>

# %%
dataset.columns
# Out:
# Index(['CustomerID', 'Age', 'Gender', 'Income', 'VisitFrequency',
#        'AverageSpend', 'PreferredCuisine', 'TimeOfVisit', 'GroupSize',
#        'DiningOccasion', 'MealType', 'OnlineReservation', 'DeliveryOrder',
#        'LoyaltyProgramMember', 'WaitTime', 'ServiceRating', 'FoodRating',
#        'AmbianceRating', 'HighSatisfaction'],
#       dtype='object')

# %%
plt.figure(figsize=(10,3))
data=dataset.head(20)
sns.pairplot(data[['CustomerID', 'GroupSize', 'WaitTime', 'FoodRating','ServiceRating']])
plt.show()

# %%
data=dataset.head(5)
x=data['PreferredCuisine']
sizes=data['AverageSpend']
plt.pie(sizes, labels=x, startangle=90, wedgeprops={"edgecolor":"darkblue"}, autopct='%1.1f%%', explode=[0,0.1,0,0.1,0.1])
plt.title('pie-chart of DiningOccasion and AverageSpend')
plt.show()

# %%
sns.set_theme(style="darkgrid")
data=dataset.head(30)
sns.relplot(data=data, kind='line', x='CustomerID', y='AverageSpend', hue='Gender')

# %%
sns.set_theme(style="darkgrid")
data=dataset[dataset.index.isin(range(1,500))]
sns.catplot(data=data, x='PreferredCuisine', y='Income', hue='Gender')
