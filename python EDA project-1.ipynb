# %% [markdown]
# #  Predict Customer Purchase Behavior

# %%
# Python Libraries install

# !pip install numpy 
# !pip install pandas
# !pip install matplotlib
# !pip install seaborn

# %%
# importing python libraries

import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
# dataset load

data_set = pd.read_csv(r"C:\Users\raghu\OneDrive\Desktop\sudeshna's folder\Data Analyst project\Data sets\customer_purchase_data.csv")

data_set        # data set display
# Out:
#       Age  Gender   AnnualIncome  NumberOfPurchases  ProductCategory  \
# 0      40       1   66120.267939                  8                0
# 1      20       1   23579.773583                  4                2
# 2      27       1  127821.306432                 11                2
# 3      24       1  137798.623120                 19                3
# 4      31       1   99300.964220                 19                1
# ...   ...     ...            ...                ...              ...
# 1495   39       1   65048.141834                 13                0
# 1496   67       1   28775.331069                 18                2
# 1497   40       1   57363.247541                  7                4
# 1498   63       0  134021.775532                 16                2
# 1499   50       0   52625.665974                 13                0
#
#       TimeSpentOnWebsite  LoyaltyProgram  DiscountsAvailed  PurchaseStatus
# ...

# %%
# Top 5 rows in the data set

data_set.head()
# Out:
#    Age  Gender   AnnualIncome  NumberOfPurchases  ProductCategory  \
# 0   40       1   66120.267939                  8                0
# 1   20       1   23579.773583                  4                2
# 2   27       1  127821.306432                 11                2
# 3   24       1  137798.623120                 19                3
# 4   31       1   99300.964220                 19                1
#
#    TimeSpentOnWebsite  LoyaltyProgram  DiscountsAvailed  PurchaseStatus
# 0           30.568601               0                 5               1
# 1           38.240097               0                 5               0
# 2           31.633212               1                 0               1
# 3           46.167059               0                 4               1
# 4           19.823592               0                 0               1

# %%
# last 5 rows in the data set or bottom 5 rows

data_set.tail()
# Out:
#       Age  Gender   AnnualIncome  NumberOfPurchases  ProductCategory  \
# 1495   39       1   65048.141834                 13                0
# 1496   67       1   28775.331069                 18                2
# 1497   40       1   57363.247541                  7                4
# 1498   63       0  134021.775532                 16                2
# 1499   50       0   52625.665974                 13                0
#
#       TimeSpentOnWebsite  LoyaltyProgram  DiscountsAvailed  PurchaseStatus
# 1495           34.590743               0                 5               1
# 1496           17.625707               0                 1               1
# 1497           12.206033               0                 0               0
# 1498           37.311634               1                 0               1
# 1499           25.348017               1                 4               1

# %%
# rows and columns in the data set

data_set.shape
# Out:
# (1500, 9)

# %%
# shows column names in the dataset

data_set.columns
# Out:
# Index(['Age', 'Gender', 'AnnualIncome', 'NumberOfPurchases', 'ProductCategory',
#        'TimeSpentOnWebsite', 'LoyaltyProgram', 'DiscountsAvailed',
#        'PurchaseStatus'],
#       dtype='object')

# %%
# columns count without names

print(len(data_set.columns))
# Out:
# 9

# %%
# shows entire information about dataset with memory

data_set.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1500 entries, 0 to 1499
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Age                 1500 non-null   int64
#  1   Gender              1500 non-null   int64
#  2   AnnualIncome        1500 non-null   float64
#  3   NumberOfPurchases   1500 non-null   int64
#  4   ProductCategory     1500 non-null   int64
#  5   TimeSpentOnWebsite  1500 non-null   float64
#  6   LoyaltyProgram      1500 non-null   int64
#  7   DiscountsAvailed    1500 non-null   int64
#  8   PurchaseStatus      1500 non-null   int64
# dtypes: float64(2), int64(7)
# memory usage: 105.6 KB

# %%
# null values
# method--1
data_set.isna()
# Out:
#         Age  Gender  AnnualIncome  NumberOfPurchases  ProductCategory  \
# 0     False   False         False              False            False
# 1     False   False         False              False            False
# 2     False   False         False              False            False
# 3     False   False         False              False            False
# 4     False   False         False              False            False
# ...     ...     ...           ...                ...              ...
# 1495  False   False         False              False            False
# 1496  False   False         False              False            False
# 1497  False   False         False              False            False
# 1498  False   False         False              False            False
# 1499  False   False         False              False            False
#
#       TimeSpentOnWebsite  LoyaltyProgram  DiscountsAvailed  PurchaseStatus
# ...

# %%
# method--2
data_set.isnull()     # shows null values in columns
# Out:
#         Age  Gender  AnnualIncome  NumberOfPurchases  ProductCategory  \
# 0     False   False         False              False            False
# 1     False   False         False              False            False
# 2     False   False         False              False            False
# 3     False   False         False              False            False
# 4     False   False         False              False            False
# ...     ...     ...           ...                ...              ...
# 1495  False   False         False              False            False
# 1496  False   False         False              False            False
# 1497  False   False         False              False            False
# 1498  False   False         False              False            False
# 1499  False   False         False              False            False
#
#       TimeSpentOnWebsite  LoyaltyProgram  DiscountsAvailed  PurchaseStatus
# ...

# %%
data_set.isnull().sum()     # shows null values in columns
# Out:
# Age                   0
# Gender                0
# AnnualIncome          0
# NumberOfPurchases     0
# ProductCategory       0
# TimeSpentOnWebsite    0
# LoyaltyProgram        0
# DiscountsAvailed      0
# PurchaseStatus        0
# dtype: int64

# %%
data_set.isna().any()      # any() method tells the boolean type values
# Out:
# Age                   False
# Gender                False
# AnnualIncome          False
# NumberOfPurchases     False
# ProductCategory       False
# TimeSpentOnWebsite    False
# LoyaltyProgram        False
# DiscountsAvailed      False
# PurchaseStatus        False
# dtype: bool

# %%
data_set.duplicated()     # shows duplicate values if present it returns true otherwise false
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1495    False
# 1496    False
# 1497    False
# 1498    False
# 1499    False
# Length: 1500, dtype: bool

# %%
data_set.duplicated().sum()   # shows count of duplicate values
# Out:
# 112

# %%
data_set.drop_duplicates(inplace=True)

# %%
data_set.duplicated().sum()
# Out:
# 0

# %%
# particular column in the dataset

data_set['Age'] 
#data_set['AnnualIncome']
# Out:
# 0       40
# 1       20
# 2       27
# 3       24
# 4       31
#         ..
# 1495    39
# 1496    67
# 1497    40
# 1498    63
# 1499    50
# Name: Age, Length: 1500, dtype: int64

# %%
data_set['Age'].head(15)
# Out:
# 0     40
# 1     20
# 2     27
# 3     24
# 4     31
# 5     66
# 6     39
# 7     64
# 8     43
# 9     20
# 10    66
# 11    70
# 12    54
# 13    64
# 14    19
# Name: Age, dtype: int64

# %%
# which applies the conditional statement in a particular column and checks the given condition
data_set['Age'] == 40
# Out:
# 0        True
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1495    False
# 1496    False
# 1497     True
# 1498    False
# 1499    False
# Name: Age, Length: 1500, dtype: bool

# %%
# tells about count of the given statement
(data_set['Age'] == 40).sum()
# Out:
# 33

# %%
# Here we write the condition in a loop and also tell about count of the given condition 
age = data_set['Age']
count = 0
for v in age:
    if v >= 65:
        print(v)
        count += 1
print("Count of values equal to :", count)
# Out:
# 66
# 66
# 70
# 70
# 67
# 66
# 67
# 66
# 68
# 66
# 70
# 65
# 68
# 68
# 68
# 70
# 70
# 65
# 68
# 70
# 68
# 70
# 65
# 65
# 69
# 68
# 69
# 66
# 66
# 68
# 66
# 70
# 69
# 66
# 70
# 70
# 68
# 65
# 65
# 68
# 67
# 65
# 66
# 67
# 67
# 68
# 66
# 65
# 66
# 66
# 66
# 69
# 66
# 68
# 68
# 68
# 70
# 68
# 65
# 68
# 68
# 69
# 68
# 67
# 66
# 70
# 68
# 66
# 69
# 69
# 69
# 65
# 68
# 70
# 69
# 65
# 68
# 70
# 69
# 67
# 65
# 66
# 69
# 68
# 70
# 66
# 65
# 67
# 66
# 65
# 66
# 68
# 69
# 70
# 68
# 67
# 68
# 70
# 69
# 69
# 69
# 68
# 69
# 65
# 69
# 68
# 70
# 68
# 65
# 68
# 68
# 67
# 69
# 69
# 65
# 66
# 69
# 65
# 70
# 69
# 65
# 69
# 66
# 66
# 65
# 70
# 68
# 70
# 67
# 70
# 66
# 66
# 65
# 68
# 66
# 65
# 68
# 67
# 66
# 65
# 66
# 70
# 66
# 65
# 67
# 70
# 68
# 67
# 70
# 65
# 69
# 69
# 69
# 68
# 66
# 70
# 67
# 68
# 66
# 66
# 68
# 69
# 66
# 68
# 65
# 69
# 67
# 66
# 69
# 67
# 66
# 66
# 69
# 68
# 68
# 66
# 70
# 69
# 69
# 70
# 68
# 66
# 69
# 66
# 70
# 70
# 67
# 68
# 69
# 68
# 67
# Count of values equal to : 191

# %%
# This method tells that the max, min,  mean...like that values
# simply tells statistical analysis of all the numeric columns in a dataset 

data_set.describe()
# Out:
#                Age       Gender   AnnualIncome  NumberOfPurchases  \
# count  1500.000000  1500.000000    1500.000000        1500.000000
# mean     44.298667     0.504667   84249.164338          10.420000
# std      15.537259     0.500145   37629.493078           5.887391
# min      18.000000     0.000000   20001.512518           0.000000
# 25%      31.000000     0.000000   53028.979155           5.000000
# 50%      45.000000     1.000000   83699.581476          11.000000
# 75%      57.000000     1.000000  117167.772858          15.000000
# max      70.000000     1.000000  149785.176481          20.000000
#
#        ProductCategory  TimeSpentOnWebsite  LoyaltyProgram  DiscountsAvailed  \
# count      1500.000000         1500.000000     1500.000000       1500.000000
# mean          2.012667           30.469040        0.326667          2.555333
# std           1.428005           16.984392        0.469151          1.705152
# ...

# %%
data_set['ProductCategory'].value_counts()   # tells that count of the given column
# Out:
# ProductCategory
# 1    331
# 4    321
# 0    289
# 3    286
# 2    273
# Name: count, dtype: int64

# %%
# tells about length of count of the given statement

print(len(data_set['ProductCategory'].value_counts()))
# Out:
# 5

# %%
# top 10 largest values using sorting method
sorting= data_set.sort_values(by='NumberOfPurchases', ascending=False)
sorting.head(10)
# Out:
#       Age  Gender   AnnualIncome  NumberOfPurchases  ProductCategory  \
# 369    41       1   66214.091357                 20                4
# 104    29       0  149326.508216                 20                4
# 384    37       0   70632.646337                 20                0
# 888    19       1  132592.432370                 20                3
# 1128   22       1   69467.302283                 20                2
# 872    51       0  144345.181779                 20                3
# 1427   69       1   74931.295681                 20                0
# 412    49       0   53708.578653                 20                2
# 1140   56       1  108429.611297                 20                2
# 1171   57       0  131153.926211                 20                3
#
#       TimeSpentOnWebsite  LoyaltyProgram  DiscountsAvailed  PurchaseStatus
# 369             4.206538               0                 0               0
# ...

# %%
data_set['NumberOfPurchases'].unique()      # tells about unique values in the given column
# Out:
# array([ 8,  4, 11, 19, 14, 16, 13, 20,  9, 17,  7,  2,  0, 12,  3, 18, 15,
#         1,  5, 10,  6], dtype=int64)

# %%
data_set['DiscountsAvailed'].unique()         # tells about unique values in the given column
# Out:
# array([5, 0, 4, 2, 3, 1], dtype=int64)

# %%
print(len(data_set['DiscountsAvailed'].value_counts()))   # length of the above cell
# Out:
# 6

# %%
data_set[['NumberOfPurchases', 'AnnualIncome']].head()  #2 columns at a time using [[ ]]
# Out:
#    NumberOfPurchases   AnnualIncome
# 0                  8   66120.267939
# 1                  4   23579.773583
# 2                 11  127821.306432
# 3                 19  137798.623120
# 4                 19   99300.964220

# %%
data_set[data_set.index == 10]          #showing only one row from dataset
# Out:
#     Age  Gender  AnnualIncome  NumberOfPurchases  ProductCategory  \
# 10   66       1  66199.993929                 11                1
#
#     TimeSpentOnWebsite  LoyaltyProgram  DiscountsAvailed  PurchaseStatus
# 10            1.415532               1                 5               1

# %%
data_set[data_set.index.isin(range(0,10))]    # retriving more than one row from dataset
# Out:
#    Age  Gender   AnnualIncome  NumberOfPurchases  ProductCategory  \
# 0   40       1   66120.267939                  8                0
# 1   20       1   23579.773583                  4                2
# 2   27       1  127821.306432                 11                2
# 3   24       1  137798.623120                 19                3
# 4   31       1   99300.964220                 19                1
# 5   66       1   37758.117475                 14                4
# 6   39       1  126883.385286                 16                3
# 7   64       1   39707.359724                 13                2
# 8   43       0  102797.301269                 20                1
# 9   20       1   63854.921080                 16                0
#
#    TimeSpentOnWebsite  LoyaltyProgram  DiscountsAvailed  PurchaseStatus
# 0           30.568601               0                 5               1
# 1           38.240097               0                 5               0
# ...

# %%
#data_set.to_numpy()     # to convert the entire data into array
# Out:
# array([[4.00000000e+01, 1.00000000e+00, 6.61202679e+04, ...,
#         0.00000000e+00, 5.00000000e+00, 1.00000000e+00],
#        [2.00000000e+01, 1.00000000e+00, 2.35797736e+04, ...,
#         0.00000000e+00, 5.00000000e+00, 0.00000000e+00],
#        [2.70000000e+01, 1.00000000e+00, 1.27821306e+05, ...,
#         1.00000000e+00, 0.00000000e+00, 1.00000000e+00],
#        ...,
#        [4.00000000e+01, 1.00000000e+00, 5.73632475e+04, ...,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [6.30000000e+01, 0.00000000e+00, 1.34021776e+05, ...,
#         1.00000000e+00, 0.00000000e+00, 1.00000000e+00],
#        [5.00000000e+01, 0.00000000e+00, 5.26256660e+04, ...,
#         1.00000000e+00, 4.00000000e+00, 1.00000000e+00]])

# %%
data_set  #data set dispaly
# Out:
#       Age  Gender   AnnualIncome  NumberOfPurchases  ProductCategory  \
# 0      40       1   66120.267939                  8                0
# 1      20       1   23579.773583                  4                2
# 2      27       1  127821.306432                 11                2
# 3      24       1  137798.623120                 19                3
# 4      31       1   99300.964220                 19                1
# ...   ...     ...            ...                ...              ...
# 1495   39       1   65048.141834                 13                0
# 1496   67       1   28775.331069                 18                2
# 1497   40       1   57363.247541                  7                4
# 1498   63       0  134021.775532                 16                2
# 1499   50       0   52625.665974                 13                0
#
#       TimeSpentOnWebsite  LoyaltyProgram  DiscountsAvailed  PurchaseStatus
# ...

# %%
data_set.plot()       # represents the creation of a line plot for each column in the Dataset.
# Out:
# <Axes: >

# %%
# graph of bottom 5 values for given column
data_set['NumberOfPurchases'].head(15).plot()
# Out:
# <Axes: >

# %%
data_set['AnnualIncome'].nlargest(n=5)      # shows that given column in largest 5 values
# Out:
# 468     149785.176481
# 1169    149716.711239
# 715     149570.591001
# 657     149523.463892
# 868     149406.877105
# Name: AnnualIncome, dtype: float64

# %%
data_set['AnnualIncome'].nlargest(n=5).plot()     # line graph for the given statement
# Out:
# <Axes: >

# %%
x = (data_set['NumberOfPurchases'].head(20))

y = (data_set['Age'].head(20))

plt.bar(x, y)

plt.show()

# %%
data_set.head()
# Out:
#    Age  Gender   AnnualIncome  NumberOfPurchases  ProductCategory  \
# 0   40       1   66120.267939                  8                0
# 1   20       1   23579.773583                  4                2
# 2   27       1  127821.306432                 11                2
# 3   24       1  137798.623120                 19                3
# 4   31       1   99300.964220                 19                1
#
#    TimeSpentOnWebsite  LoyaltyProgram  DiscountsAvailed  PurchaseStatus
# 0           30.568601               0                 5               1
# 1           38.240097               0                 5               0
# 2           31.633212               1                 0               1
# 3           46.167059               0                 4               1
# 4           19.823592               0                 0               1

# %%
data_set[['NumberOfPurchases', 'ProductCategory']].head()
# Out:
#    NumberOfPurchases  ProductCategory
# 0                  8                0
# 1                  4                2
# 2                 11                2
# 3                 19                3
# 4                 19                1

# %%
sns.barplot(data = data_set, x='NumberOfPurchases', y='ProductCategory')
# Out:
# <Axes: xlabel='NumberOfPurchases', ylabel='ProductCategory'>

# %%
data1 = data_set[data_set.index.isin(range(1,30))]
sns.barplot(data = data1, x='DiscountsAvailed', y = 'TimeSpentOnWebsite')
# Out:
# <Axes: xlabel='DiscountsAvailed', ylabel='TimeSpentOnWebsite'>

# %%
df=data_set[data_set.index.isin(range(2,20))]
df1=df.loc[df['AnnualIncome']>=25000.00]
sns.barplot(data = df1, y= 'AnnualIncome', x= 'Age')
# Out:
# <Axes: xlabel='Age', ylabel='AnnualIncome'>

# %%
df=data_set[data_set.index.isin(range(2,20))]
df1=df.loc[df['AnnualIncome']>=25000.00]
sns.lineplot(data = df1, x= 'ProductCategory', y= 'NumberOfPurchases')
# Out:
# <Axes: xlabel='ProductCategory', ylabel='NumberOfPurchases'>

# %%
data_set.columns
# Out:
# Index(['Age', 'Gender', 'AnnualIncome', 'NumberOfPurchases', 'ProductCategory',
#        'TimeSpentOnWebsite', 'LoyaltyProgram', 'DiscountsAvailed',
#        'PurchaseStatus'],
#       dtype='object')

# %%
data2=data_set[(data_set['Age']>=65)&(data_set['NumberOfPurchases']<19)]
sns.lineplot(x='Age', y='NumberOfPurchases', data=data2)
# Out:
# <Axes: xlabel='Age', ylabel='NumberOfPurchases'>

# %%
sns.countplot(y='NumberOfPurchases', data=data_set)
# Out:
# <Axes: xlabel='count', ylabel='NumberOfPurchases'>

# %%
dt=data_set[data_set.index.isin(range(1,20))]
sns.countplot(y='DiscountsAvailed', data=dt)
# Out:
# <Axes: xlabel='count', ylabel='DiscountsAvailed'>

# %%
sns.stripplot(x='DiscountsAvailed', y='AnnualIncome', data=data_set)
# Out:
# <Axes: xlabel='DiscountsAvailed', ylabel='AnnualIncome'>

# %%
sp=data_set[data_set['Age']>45]
sns.stripplot(y='Age', x='LoyaltyProgram', data=sp)
# Out:
# <Axes: xlabel='LoyaltyProgram', ylabel='Age'>

# %%
data=data_set[data_set.index.isin(range(2,15))]
sp = data['Age'].head(10)
mp = data['NumberOfPurchases'].head(10)

plt.figure(figsize=(9, 3))

plt.subplot(141)
plt.plot(sp, mp)
plt.subplot(142)
plt.scatter(sp, mp)
plt.subplot(143)
plt.bar(sp, mp)
plt.suptitle('Categorical Plotting btw DiscountsAvailed and ProductCategory')
plt.show()

# %%
data_set.head()
# Out:
#    Age  Gender   AnnualIncome  NumberOfPurchases  ProductCategory  \
# 0   40       1   66120.267939                  8                0
# 1   20       1   23579.773583                  4                2
# 2   27       1  127821.306432                 11                2
# 3   24       1  137798.623120                 19                3
# 4   31       1   99300.964220                 19                1
#
#    TimeSpentOnWebsite  LoyaltyProgram  DiscountsAvailed  PurchaseStatus
# 0           30.568601               0                 5               1
# 1           38.240097               0                 5               0
# 2           31.633212               1                 0               1
# 3           46.167059               0                 4               1
# 4           19.823592               0                 0               1

# %%
data=data_set.head(1000)
sns.pairplot(data[['NumberOfPurchases', 'Age', 'TimeSpentOnWebsite', 'AnnualIncome', 'DiscountsAvailed','PurchaseStatus']])

# %%
#filtering the data
data=data_set.head(50)
x=data.loc[data['Age']>65, 'AnnualIncome']
label_data=data.loc[data['Age']>65, 'Age']

#plotting the piechart
plt.pie(x, labels=label_data, autopct='%1.1f%%', startangle=150)
plt.title('Piechart for Age and AnnualIncome ')
#plt.axis('equal')
plt.show()

# %%
data=data_set[['AnnualIncome', 'TimeSpentOnWebsite']].head()
annualincome_lable=data['AnnualIncome']
sizes=data['TimeSpentOnWebsite']
plt.pie(sizes, labels=annualincome_lable, colors=['olivedrab', 'rosybrown', 'grey', 'brown', 'blue'])
plt.title('piechart for TimeSpentOnWebsite and AnnualIncome ')
plt.show()

# %%
data=data_set[['ProductCategory','NumberOfPurchases']].head()
plot=data.plot.pie(x='NumberOfPurchases', y='ProductCategory', figsize=(6,6))
plot=data.plot.pie(subplots=True, fig=(6,4))

# %%
correlation = data_set.corr()
correlation['PurchaseStatus'].sort_values(ascending=False)
# Out:
# PurchaseStatus        1.000000
# LoyaltyProgram        0.310838
# DiscountsAvailed      0.303297
# TimeSpentOnWebsite    0.277112
# NumberOfPurchases     0.222691
# AnnualIncome          0.188214
# ProductCategory       0.007346
# Gender                0.002627
# Age                  -0.255747
# Name: PurchaseStatus, dtype: float64

# %%
plt.figure(figsize=(8,8))
sns.heatmap(data=correlation, cmap="magma", square=True, linewidth=0.1,annot=True)
# Out:
# <Axes: >
